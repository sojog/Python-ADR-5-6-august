# %% [markdown]
# # pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter([10, 20, 30], [1, 2, 3]);

# %%
plt.plot([10, 20, 30], [1, 2, 3]);

# %%
plt.scatter([10, 20, 30], [1, 2, 3]);
plt.plot([10, 20, 30], [1, 2, 3]);

# %%
plt.bar([10, 20, 30], [1, 2, 3]);

# %%
plt.barh([10, 20, 30], [1, 2, 3]);

# %%
plt.pie([10, 20, 30]);
