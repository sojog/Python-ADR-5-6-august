# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("recipes.csv", index_col=0)
df.head(2)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0  Classic Margherita Pizza               20               15         4
# 1       Vegetarian Stir-Fry               15               20         3
#
#    caloriesPerServing  reviewCount
# 0                 300           98
# 1                 250           26

# %%
df.dtypes
# Out:
# name                  object
# prepTimeMinutes        int64
# cookTimeMinutes        int64
# servings               int64
# caloriesPerServing     int64
# reviewCount            int64
# dtype: object

# %%
df.describe()
# Out:
#        prepTimeMinutes  cookTimeMinutes   servings  caloriesPerServing  \
# count        30.000000        30.000000  30.000000           30.000000
# mean         21.500000        19.500000   4.366667          331.333333
# std           9.751216        12.821722   3.978245          122.776313
# min           5.000000         0.000000   1.000000          120.000000
# 25%          15.000000        11.250000   3.000000          227.500000
# 50%          20.000000        20.000000   4.000000          320.000000
# 75%          30.000000        28.750000   4.000000          415.000000
# max          45.000000        45.000000  24.000000          550.000000
#
#        reviewCount
# count    30.000000
# mean     51.633333
# std      30.673456
# min       0.000000
# 25%      27.000000
# 50%      54.000000
# 75%      81.000000
# max      98.000000

# %%
df[["name", "prepTimeMinutes"]].sort_values(by="prepTimeMinutes")
# Out:
#                                  name  prepTimeMinutes
# 29               Brazilian Caipirinha                5
# 24          Blueberry Banana Smoothie               10
# 8                       Caprese Salad               10
# 21                        Mango Lassi               10
# 1                 Vegetarian Stir-Fry               15
# 2              Chocolate Chip Cookies               15
# 3               Chicken Alfredo Pasta               15
# 4                 Mango Salsa Chicken               15
# 25        Mexican Street Corn (Elote)               15
# 6             Tomato Basil Bruschetta               15
# 9                 Shrimp Scampi Pasta               15
# 16           Moroccan Chickpea Tagine               15
# 28              Lebanese Falafel Wrap               15
# 20                   Thai Green Curry               20
# 15                Japanese Ramen Soup               20
# 0            Classic Margherita Pizza               20
# ...

# %%
df[["name", "prepTimeMinutes", "servings"]].sort_values(by="prepTimeMinutes")
# Out:
#                                  name  prepTimeMinutes  servings
# 29               Brazilian Caipirinha                5         1
# 24          Blueberry Banana Smoothie               10         1
# 8                       Caprese Salad               10         2
# 21                        Mango Lassi               10         2
# 1                 Vegetarian Stir-Fry               15         3
# 2              Chocolate Chip Cookies               15        24
# 3               Chicken Alfredo Pasta               15         4
# 4                 Mango Salsa Chicken               15         3
# 25        Mexican Street Corn (Elote)               15         4
# 6             Tomato Basil Bruschetta               15         6
# 9                 Shrimp Scampi Pasta               15         3
# 16           Moroccan Chickpea Tagine               15         4
# 28              Lebanese Falafel Wrap               15         2
# ...

# %%
df[["name", "prepTimeMinutes", "servings"]].sort_values(by=["prepTimeMinutes", "servings"],ascending=(True, False))
# Out:
#                                  name  prepTimeMinutes  servings
# 29               Brazilian Caipirinha                5         1
# 8                       Caprese Salad               10         2
# 21                        Mango Lassi               10         2
# 24          Blueberry Banana Smoothie               10         1
# 2              Chocolate Chip Cookies               15        24
# 6             Tomato Basil Bruschetta               15         6
# 3               Chicken Alfredo Pasta               15         4
# 16           Moroccan Chickpea Tagine               15         4
# 25        Mexican Street Corn (Elote)               15         4
# 1                 Vegetarian Stir-Fry               15         3
# 4                 Mango Salsa Chicken               15         3
# 9                 Shrimp Scampi Pasta               15         3
# 28              Lebanese Falafel Wrap               15         2
# ...

# %%
df.head(2)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0  Classic Margherita Pizza               20               15         4
# 1       Vegetarian Stir-Fry               15               20         3
#
#    caloriesPerServing  reviewCount
# 0                 300           98
# 1                 250           26

# %%
df["caloriesPerServing"].min(), df["caloriesPerServing"].max()
# Out:
# (np.int64(120), np.int64(550))

# %%
df [  (df["caloriesPerServing"]  > 200) &     (df["caloriesPerServing"]  <  300)]
# Out:
#                                  name  prepTimeMinutes  cookTimeMinutes  \
# 1                 Vegetarian Stir-Fry               15               20
# 5           Quinoa Salad with Avocado               20               15
# 14  Saag (Spinach) with Makki di Roti               40               30
# 23                     Turkish Kebabs               25               15
# 24          Blueberry Banana Smoothie               10                0
# 26                    Russian Borscht               30               40
#
#     servings  caloriesPerServing  reviewCount
# 1          3                 250           26
# 5          4                 280           59
# 14         3                 280           86
# 23         4                 280           78
# 24         1                 220           30
# 26         6                 220           39

# %%
df[["prepTimeMinutes"]].min()
# Out:
# prepTimeMinutes    5
# dtype: int64

# %%
df [df["prepTimeMinutes"] ==    df["prepTimeMinutes"].min()]
# Out:
#                     name  prepTimeMinutes  cookTimeMinutes  servings  \
# 29  Brazilian Caipirinha                5                0         1
#
#     caloriesPerServing  reviewCount
# 29                 150           55

# %%
column = "servings"


df [df[column] ==    df[column].min()]
# Out:
#                          name  prepTimeMinutes  cookTimeMinutes  servings  \
# 24  Blueberry Banana Smoothie               10                0         1
# 29       Brazilian Caipirinha                5                0         1
#
#     caloriesPerServing  reviewCount
# 24                 220           30
# 29                 150           55

# %%
column = "servings"


df [df[column] ==    df[column].max()]
# Out:
#                      name  prepTimeMinutes  cookTimeMinutes  servings  \
# 2  Chocolate Chip Cookies               15               10        24
#
#    caloriesPerServing  reviewCount
# 2                 150           13

# %%
df.groupby("servings").agg(['count'])
# Out:
#           name prepTimeMinutes cookTimeMinutes caloriesPerServing reviewCount
#          count           count           count              count       count
# servings
# 1            2               2               2                  2           2
# 2            5               5               5                  5           5
# 3            4               4               4                  4           4
# 4           12              12              12                 12          12
# 5            1               1               1                  1           1
# 6            5               5               5                  5           5
# 24           1               1               1                  1           1

# %%
df.groupby("servings").agg(['count'])["name"]
# Out:
#           count
# servings
# 1             2
# 2             5
# 3             4
# 4            12
# 5             1
# 6             5
# 24            1

# %%
df[df["servings"] == 3]
# Out:
#                                  name  prepTimeMinutes  cookTimeMinutes  \
# 1                 Vegetarian Stir-Fry               15               20
# 4                 Mango Salsa Chicken               15               25
# 9                 Shrimp Scampi Pasta               15               20
# 14  Saag (Spinach) with Makki di Roti               40               30
#
#     servings  caloriesPerServing  reviewCount
# 1          3                 250           26
# 4          3                 380           63
# 9          3                 400            5
# 14         3                 280           86

# %%
df[df["servings"] == 5]
# Out:
#           name  prepTimeMinutes  cookTimeMinutes  servings  \
# 12  Aloo Keema               25               35         5
#
#     caloriesPerServing  reviewCount
# 12                 380           53

# %%
df.head(2)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0  Classic Margherita Pizza               20               15         4
# 1       Vegetarian Stir-Fry               15               20         3
#
#    caloriesPerServing  reviewCount
# 0                 300           98
# 1                 250           26

# %%
df.drop(4)
# Out:
#                                  name  prepTimeMinutes  cookTimeMinutes  \
# 0            Classic Margherita Pizza               20               15
# 1                 Vegetarian Stir-Fry               15               20
# 2              Chocolate Chip Cookies               15               10
# 3               Chicken Alfredo Pasta               15               20
# 5           Quinoa Salad with Avocado               20               15
# 6             Tomato Basil Bruschetta               15               10
# 7          Beef and Broccoli Stir-Fry               20               15
# 8                       Caprese Salad               10                0
# 9                 Shrimp Scampi Pasta               15               20
# 10                    Chicken Biryani               30               45
# 11                     Chicken Karahi               20               30
# 12                         Aloo Keema               25               35
# ...

# %%
df.drop("reviewCount", axis=1).head(2)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0  Classic Margherita Pizza               20               15         4
# 1       Vegetarian Stir-Fry               15               20         3
#
#    caloriesPerServing
# 0                 300
# 1                 250

# %%
df.rename(columns={
    "prepTimeMinutes":"timpPreparare",
    "cookTimeMinutes" : "timpCoacere"
})
# Out:
#                                  name  timpPreparare  timpCoacere  servings  \
# 0            Classic Margherita Pizza             20           15         4
# 1                 Vegetarian Stir-Fry             15           20         3
# 2              Chocolate Chip Cookies             15           10        24
# 3               Chicken Alfredo Pasta             15           20         4
# 4                 Mango Salsa Chicken             15           25         3
# 5           Quinoa Salad with Avocado             20           15         4
# 6             Tomato Basil Bruschetta             15           10         6
# 7          Beef and Broccoli Stir-Fry             20           15         4
# 8                       Caprese Salad             10            0         2
# 9                 Shrimp Scampi Pasta             15           20         3
# 10                    Chicken Biryani             30           45         6
# ...

# %%
df.head(2)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0  Classic Margherita Pizza               20               15         4
# 1       Vegetarian Stir-Fry               15               20         3
#
#    caloriesPerServing  reviewCount
# 0                 300           98
# 1                 250           26

# %%
numeric_df = df.drop("name", axis=1)
numeric_df.head(2)
# Out:
#    prepTimeMinutes  cookTimeMinutes  servings  caloriesPerServing  reviewCount
# 0               20               15         4                 300           98
# 1               15               20         3                 250           26

# %%
df.head(2)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0  Classic Margherita Pizza               20               15         4
# 1       Vegetarian Stir-Fry               15               20         3
#
#    caloriesPerServing  reviewCount
# 0                 300           98
# 1                 250           26

# %%
numeric_df.corr()
# Out:
#                     prepTimeMinutes  cookTimeMinutes  servings  \
# prepTimeMinutes            1.000000         0.606074  0.078667
# cookTimeMinutes            0.606074         1.000000  0.064561
# servings                   0.078667         0.064561  1.000000
# caloriesPerServing         0.398625         0.552441 -0.210713
# reviewCount                0.128718        -0.025471 -0.241883
#
#                     caloriesPerServing  reviewCount
# prepTimeMinutes               0.398625     0.128718
# cookTimeMinutes               0.552441    -0.025471
# servings                     -0.210713    -0.241883
# caloriesPerServing            1.000000    -0.018087
# reviewCount                  -0.018087     1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(numeric_df.corr());

# %%
sns.heatmap(numeric_df.corr(), cmap="coolwarm");
